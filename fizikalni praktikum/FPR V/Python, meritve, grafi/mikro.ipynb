# %% [markdown]
# umeritev

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------
# Nastavitve za LaTeX videz
# -------------------------
plt.rcParams.update({
    "font.size": 12,
    "axes.labelsize": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "figure.figsize": (5.5, 3.5),   # primerno za \columnwidth
    "lines.linewidth": 1.5,
    "axes.grid": True,
})

# -------------------------
# Podatki
# -------------------------
x=[100, 300, 500]
y=[10,9,8]


# -------------------------
# Risanje grafa
# -------------------------
plt.figure()

plt.errorbar(x, y, fmt="o-")
plt.plot([100, 413], [8.43,8.43], color="orange")
plt.plot([413, 413], [8,8.43], color="orange")


plt.ylabel(r'$\nu[GHz]$')
plt.xlabel(r'Lega vijaka')
plt.legend()
plt.tight_layout()

# -------------------------
# Shranjevanje
# -------------------------
plt.savefig("resonanca.pdf")   # priporočeno za LaTeX


plt.show()
# Out:
# /var/folders/3_/dmq3sq0j26b_20cwrndp7kc80000gn/T/ipykernel_94754/3788018879.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# porabljena moč

# %%
plt.figure()

x=[26.7, 54.0, 89.8, 143.9, 225, 358.1]
y=[0.05, 0.22, 0.4, 0.76, 12, 12]
plt.scatter(x, y)



plt.ylabel(r'$P_m[mW]$')
plt.xlabel(r'Lega minimuma[V]')
plt.legend()
plt.tight_layout()

# -------------------------
# Shranjevanje
# -------------------------
plt.savefig("moč.pdf")   # priporočeno za LaTeX


plt.show()
# Out:
# /var/folders/3_/dmq3sq0j26b_20cwrndp7kc80000gn/T/ipykernel_93510/247840226.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Krivulja ubranosti

# %%
import pandas as pd
df=pd.read_csv("tz/0.csv")
antena1 = df.iloc[:, 0].to_numpy()
antena2 = df.iloc[:, 1].to_numpy()
antena3 = df.iloc[:, 2].to_numpy()
antena4 = df.iloc[:, 3].to_numpy()

df=pd.read_csv("tz/01.csv")
plo1 = df.iloc[:, 0].to_numpy()
plo2 = df.iloc[:, 1].to_numpy()
plo3 = df.iloc[:, 2].to_numpy()
plo4 = df.iloc[:, 3].to_numpy()

df=pd.read_csv("tz/012.csv")
bol1 = df.iloc[:, 0].to_numpy()
bol2 = df.iloc[:, 1].to_numpy()
bol3 = df.iloc[:, 2].to_numpy()
bol4 = df.iloc[:, 3].to_numpy()

plt.plot(antena2, antena3, label="antena")
plt.plot(plo2, plo3, label="kratek stik")
plt.plot(bol2, bol3, label="bolometer")
plt.plot([2,14], [-0.01, -0.01])
plt.plot([2,14], [-0.32, -0.32], color="red")
plt.plot([3.7, 3.7], [0, -1], color="black")
plt.plot([6.5,6.5], [0, -1], color="black")
plt.plot([8.8,8.8], [0, -1], color="black")
plt.xticks([1.9, 3.7, 6.5, 8.8, 13.4], [0, 0.61, 1.56, 2.34, 3.9])
plt.xlabel("razdalja[cm]")
plt.ylabel("Signal[V]")
plt.legend()
plt.savefig("ubranost.pdf")
